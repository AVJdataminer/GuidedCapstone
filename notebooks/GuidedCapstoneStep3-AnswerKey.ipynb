# %% [markdown]
# # Guided Capstone Step 3 Exploratory Data Analysis - Answer Key

# %% [markdown]
# This is the third step in the Data Science Method. We introduced this topic in the last subunit. With Data Wrangling out of the way we can progress to the Exploratory Data Analysis section.
#
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#   * Data Collection
#    * Data Organization
#   * Data Definition
#   * Data Cleaning
#
# 3.   **Exploratory Data Analysis**
#  * Build data profile tables and plots
#         - Outliers & Anomalies
#  * Explore data relationships
#  * Identification and creation of features
#
# 4.   Pre-processing and Training Data Development
#   * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
# 5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages as we did in step 2 and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
os.getcwd()
# Out:
# '/Users/aidenjohnson/Documents/project'

# %% [markdown]
# **<font color='teal'> If you need to change your path refer back to step 2 on how to do that. Then load the csv file you created in step 2, remember it should be saved inside your data subfolder and print the first five rows.</font>**

# %%
file='data/step2_output.csv'
df=pd.read_csv(file)
df.head()
# Out:
#                   Name   Region    state  summit_elev  vertical_drop  \
# 0       Alyeska Resort   Alaska   Alaska         3939           2500
# 1  Eaglecrest Ski Area   Alaska   Alaska         2600           1540
# 2     Hilltop Ski Area   Alaska   Alaska         2090            294
# 3     Arizona Snowbowl  Arizona  Arizona        11500           2300
# 4  Sunrise Park Resort  Arizona  Arizona        11100           1800
#
#    base_elev  trams  fastEight  fastSixes  fastQuads  ...  LongestRun_mi  \
# 0        250      1        0.0          0          2  ...            1.0
# 1       1200      0        0.0          0          0  ...            2.0
# 2       1796      0        0.0          0          0  ...            1.0
# 3       9200      0        0.0          1          0  ...            2.0
# 4       9200      0        0.0          0          1  ...            1.2
#
#    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# 0             1610.0           113.0             150.0       60.0
# 1              640.0            60.0              45.0       44.0
# 2               30.0            30.0             150.0       36.0
# 3              777.0           104.0             122.0       81.0
# 4              800.0            80.0             115.0       49.0
#
#    averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0            669.0          65.0          85.0              150.0
# 1            350.0          47.0          53.0               90.0
# 2             69.0          30.0          34.0              152.0
# 3            260.0          89.0          89.0              122.0
# 4            250.0          74.0          78.0              104.0
#
#    NightSkiing_ac
# 0           550.0
# 1             0.0
# 2            30.0
# 3             0.0
# 4            80.0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Build data profile tables and plots

# %% [markdown]
# **<font color='teal'> Print out the summary stats table transposed to fit on the screen using the `describe()` function.</font>**

# %%
df.describe().T
# Out:
#                    count         mean          std    min      25%  \
# summit_elev        330.0  4591.818182  3735.535934  315.0  1403.75
# vertical_drop      330.0  1215.427273   947.864557   60.0   461.25
# base_elev          330.0  3374.000000  3117.121621   70.0   869.00
# trams              330.0     0.172727     0.559946    0.0     0.00
# fastEight          330.0     0.003030     0.055048    0.0     0.00
# fastSixes          330.0     0.184848     0.651685    0.0     0.00
# fastQuads          330.0     1.018182     2.198294    0.0     0.00
# quad               330.0     0.933333     1.312245    0.0     0.00
# triple             330.0     1.500000     1.619130    0.0     0.00
# double             330.0     1.833333     1.815028    0.0     1.00
# surface            330.0     2.621212     2.059636    0.0     1.00
# total_chairs       330.0     8.266667     5.798683    0.0     5.00
# Runs               330.0    48.214724    46.081366    3.0    19.00
# TerrainParks       330.0     2.384848     2.109556    0.0     1.00
# LongestRun_mi      330.0     1.433231     1.147352    0.0     0.60
# SkiableTerrain_ac  330.0   739.801223  1807.868079    8.0    85.00
# Snow Making_ac     330.0   150.496970   249.854380    0.0    30.00
# daysOpenLastYear   330.0   115.103943    32.231212    3.0   100.00
# yearsOpen          330.0    63.656535   109.263494    6.0    50.00
# averageSnowfall    330.0   185.316456   133.424094   18.0    71.25
# AdultWeekday       330.0    57.916957    23.898798   15.0    43.00
# AdultWeekend       330.0    64.166810    22.571324   17.0    49.00
# projectedDaysOpen  330.0   120.053004    28.742976   30.0   101.25
# NightSkiing_ac     330.0    56.890909    93.464882    0.0     0.00
#
#                            50%          75%      max
# summit_elev        3127.500000  7806.000000  13487.0
# vertical_drop       964.500000  1800.000000   4425.0
# base_elev          1561.500000  6325.250000  10800.0
# trams                 0.000000     0.000000      4.0
# fastEight             0.000000     0.000000      1.0
# fastSixes             0.000000     0.000000      6.0
# fastQuads             0.000000     1.000000     15.0
# quad                  0.000000     1.000000      8.0
# triple                1.000000     2.000000      8.0
# double                1.000000     3.000000     14.0
# surface               2.000000     3.000000     15.0
# total_chairs          7.000000    10.000000     41.0
# Runs                 34.000000    60.000000    341.0
# TerrainParks          2.000000     3.000000     14.0
# LongestRun_mi         1.000000     2.000000      6.0
# SkiableTerrain_ac   200.000000   739.801223  26819.0
# Snow Making_ac       86.000000   192.000000   3379.0
# daysOpenLastYear    115.103943   130.000000    305.0
# yearsOpen            58.000000    68.750000   2019.0
# averageSnowfall     158.000000   278.750000    669.0
# AdultWeekday         57.916957    67.000000    179.0
# AdultWeekend         64.166810    72.000000    179.0
# projectedDaysOpen   120.053004   136.000000    305.0
# NightSkiing_ac       27.000000    83.750000    650.0

# %% [markdown]
# **<font color='teal'> Histograms are an excellent way to review the range and density of values for each numeric features in your data set and build data profiles. Plot the histograms for all numeric features and adjust the bins size to 25.</font>**

# %%
hist = df.hist(bins=25,figsize =(25,25))

# %% [markdown]
# Look for similarities in the features that may indicate that they are duplicates or highly correlated features. Make a note of your findings and any other interesting insights you find about these numeric features.

# %% [markdown]
# **<font color='teal'> Okay, now you should be getting a sense for what the data look like. Let's create a barplot for the categorical features `Region` and `state` where the heights of the bars are the counts of each level in that variable. </font>**

# %% [markdown]
# **<font color='teal'>State Levels Plot</font>**

# %%
f, ax = plt.subplots(figsize=(10, 10))
x = pd.DataFrame(df.state.value_counts())
names = list(x.index)
values = list(x.state)
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# **<font color='teal'>Region Levels Plot</font>**

# %%
f, ax = plt.subplots(figsize=(10, 10))
x = pd.DataFrame(df.Region.value_counts())
names = list(x.index)
values = list(x.Region)
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# By reviewing the State and Regions counts plots you should notice that the Region feature is nearly identical to the state and therfore we can remove from the dataframe.**<font color='teal'> Remove the `Region` column using the drop function.</font>**

# %%
df=df.drop(['Region'],axis =1)
df.columns
# Out:
# Index(['Name', 'state', 'summit_elev', 'vertical_drop', 'base_elev', 'trams',
#        'fastEight', 'fastSixes', 'fastQuads', 'quad', 'triple', 'double',
#        'surface', 'total_chairs', 'Runs', 'TerrainParks', 'LongestRun_mi',
#        'SkiableTerrain_ac', 'Snow Making_ac', 'daysOpenLastYear', 'yearsOpen',
#        'averageSnowfall', 'AdultWeekday', 'AdultWeekend', 'projectedDaysOpen',
#        'NightSkiing_ac'],
#       dtype='object')

# %% [markdown]
# ## Anamolies & Outliers - Review boxplots

# %% [markdown]
# **<font color='teal'> Print boxplot for every column</font>**

# %%
boxplot = df.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %% [markdown]
# You need to create boxplots and  histograms to evaluate the data for potential outliers or data anomalies. Generally, outliers are defined as observations that differ significantly from the other values in the dataset or feature.
#
# Reviewing the distribution of values by column will help you  interpret this. Outliers are extreme values that fall far outside the mean and standard deviation of a set of observations. They  can mislead the training process in building machine learning models. Outliers may be real anomalies in the observations or artificial errors.
#
# One method for outlier analysis is extreme value analysis using a boxplot, which assumes a normal distribution. The figure below describes the components of a boxplot. Notice the outlier is the point outside the upper whisker end.
#
# ![](AnnotatedBoxplot.png)
# <font color='teal'>**Follow these steps:
#
# 1. Create boxplots - earlier step
# 2. Apply outlier removal using the Interquartile range or replacement
# 3. Review how many observations were removed**</font>

# %%
#Remove outliers based on IQR
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

dfno = df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]
boxplot = dfno.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %%
print(df.shape)
dfno.shape
# Out:
# (330, 26)
# (176, 26)

# %% [markdown]
# There are many possible response variables you could have identified in the Step 1 guided capstone exercise. However, for the rest of this guided capstone project we will focus on increasing revenue by increasing the lift ticket prices and the number of days the resort is open per year. In this case, we need to investigate the expected lift ticket price for Big Mountain based on all the other given resort characteristics. In addition, we want to predict the number of days open each season.

# %% [markdown]
# <font color='teal'>**Review the `AdultWeekday`,`AdultWeekend` response variable distributions**</font>

# %%
df['AdultWeekday'].hist()

# %%
df['AdultWeekend'].hist()

# %% [markdown]
# <font color='teal'>**Review the `daysOpenLastYear`,`projecteDaysOpen` response variable distributions**</font>

# %%
df['daysOpenLastYear'].hist()

# %%
df['projectedDaysOpen'].hist()

# %% [markdown]
# After reviewing these respons varible distributions, there doesn't appear to be any data issues to mitigate. Now, we move on to investigating feature relationship and interactions between the features the response.

# %% [markdown]
# # Explore data relationships

# %% [markdown]
# <font color='teal'>**Create pairplots or what is commonly referred to as biplots**</font>

# %%
#pair plots
g = sns.pairplot(df)

# %% [markdown]
# # Identification and creation of features

# %% [markdown]
# <font color='teal'>**Create a Pearson correlation heatmap**</font>

# %%
corr = df.corr()
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col1 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col2 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col3 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col4 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col5 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col6 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col7 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col8 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col9 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col10 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col11 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col12 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col13 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col14 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col15 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col16 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col17 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col18 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col19 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col20 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col21 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col22 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row0_col23 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col0 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col2 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col3 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col4 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col5 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col6 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col7 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col8 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col9 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col10 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col11 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col12 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col13 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col14 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col15 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col16 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col17 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col18 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col19 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col20 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col21 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col22 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row1_col23 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col0 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col1 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col3 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col4 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col5 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col6 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col7 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col8 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col9 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col10 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_10f3900c_34e9_11ea_a06f_3035adabbe76row2_col11 {
#             background-color:  #7b9ff9;

# %% [markdown]
# When reviewing the Pearson correlation coefficient heat map you can see substantial differences in the correlations compared to the response variable(s) as well as in the features when compared to each other. The heatmap helps identify features that suffer from Multi-collinearity.

# %% [markdown]
# <font color='teal'>**Use the correlation matrix displayed in the heatmap to select and remove collinear features. Remember to exclude the response variable(s) from the matrix to ensure they are retained in our final model development data set. Then select those features that are more than 95% correlated for removal.**</font>

# %%
# Create correlation matrix
corr_matrix = df.drop(['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'], axis=1).corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
print('Features selected to drop include',to_drop)
# Out:
# Features selected to drop include ['base_elev']

# %%
print('Reduced dataframe size ',df.drop(df[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size  (330, 25)

# %% [markdown]
# Now we address the feature creation piece of this step. We can create additional features through many methods such as: combining several features, grouping features into bins, or even by applying an unsupervised classification algorithm, such as Kmeans clustering and using the clusters as features in our model development dataset.

# %% [markdown]
# Run the next two cells below to create an Elbow plot. The Elbow plot is a diagnostic tool that helps you determine the number of clusters to include in your kmeans clustering implementation. In this example, the error between clusters and within clusters is compared for a range of 1 to 11 clusters, and it appears the elbow is between two and four, therefore we set the parameter k = 3.

# %%
#from sklearn.cluster import KMeans
#x = df.drop(['Name','state'], axis =1).values

# %%
#Error =[]
#for i in range(1, 11):
#   kmeans = KMeans(n_clusters = i).fit(x)
#    kmeans.fit(x)
#    Error.append(kmeans.inertia_)
#import matplotlib.pyplot as plt
#plt.plot(range(1, 11), Error)
#plt.title('Elbow method')
#plt.xlabel('No of clusters')
#plt.ylabel('Error')
#plt.show()

# %% [markdown]
# <font color='teal'>**Fit the kmeans algorithm with the k parameter set to three and plot the results.**</font>

# %%
kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# <font color='teal'>**Add the clusters to your dataframe as a new column to include in the next step and write the updated dataframe out as csv. Save the dataframe in the data folder and name it `step3_output.csv`.**</font>

# %%
df['clusters']=y_kmeans3

# %%
df.to_csv('data/step3_output.csv',index=False)
